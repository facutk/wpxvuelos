# %% [markdown]
# # Building images-by-country-id.json dataset
#
# This notebook is a step by step guide on how to create and update the current dataset

# %% [markdown]
# ## Requirements
#
# ### Download SkyScanner supported Countries
# ```sh
# wget http://partners.api.skyscanner.net/apiservices/geo/v1.0?apikey=prtl6749387986743898559646983194 \
#   --header 'content-type: application/json' \
#   > geo.json
# ```
#
# ### Download and extract Unsplash Research dataset
# ```sh
# wget https://unsplash.com/data/lite/latest -O unsplash-research-dataset-lite-latest.zip
# unzip unsplash-research-dataset-lite-latest.zip -d unsplash-research-dataset-lite-latest
# ```

# %% [markdown]
# ## Loading libraries

# %%
import numpy as np
import pandas as pd
import glob
import json

# %% [markdown]
# ## Loading the datasets in Pandas
#
# Make sure that you correctly point to the correct path.

# %%
path = './unsplash-research-dataset-lite-latest/'
documents = ['photos', 'keywords', 'collections', 'conversions', 'colors']
datasets = {}

for doc in documents:
  files = glob.glob(path + doc + ".tsv*")

  subsets = []
  for filename in files:
    df = pd.read_csv(filename, sep='\t', header=0)
    subsets.append(df)

  datasets[doc] = pd.concat(subsets, axis=0, ignore_index=True)

# %% [markdown]
# ## Exploring the datasets
#
# Here are the first couple of rows from each dataset, as an example.
#
# Enjoy the exploration!

# %%
datasets['photos'].head()
# Out:
#       photo_id                                photo_url  \
# 0  2Q8zDWkj0Yw  https://unsplash.com/photos/2Q8zDWkj0Yw
# 1  tsBDNuCJiLg  https://unsplash.com/photos/tsBDNuCJiLg
# 2  A93gsuMxVcE  https://unsplash.com/photos/A93gsuMxVcE
# 3  oYIdH6bFssk  https://unsplash.com/photos/oYIdH6bFssk
# 4  wgLPy2YBXuc  https://unsplash.com/photos/wgLPy2YBXuc
#
#                                      photo_image_url  \
# 0  https://images.unsplash.com/photo-141520117961...
# 1  https://images.unsplash.com/photo-141768928330...
# 2  https://images.unsplash.com/photo-142981401899...
# 3  https://images.unsplash.com/photo-143275722183...
# 4  https://images.unsplash.com/photo-143205996405...
#
#            photo_submitted_at photo_featured  photo_width  photo_height  \
# 0  2014-11-05 15:26:26.678711              t         4192          2794
# 1  2014-12-04 10:31:44.647012              t         4324          2880
# 2  2015-04-23 18:33:44.024841              t         2000          1333
# 3   2015-05-27 20:07:28.35245              t         4288          2848
# 4  2015-05-19 18:26:15.223161              t         5312          2988
#
#    photo_aspect_ratio      photo_description photographer_username  \
# 0                1.50                    NaN         lanceanderson
# 1                1.50    Surfer in the ocean         thehungryjpeg
# 2                1.50     Barren Countryside          jeremydgreat
# 3                1.51  Lightbulb reflections             chelaxydp
# 4                1.78                    NaN                 csogi
#
#                 ...               photo_location_longitude  \
# 0               ...                                    NaN
# 1               ...                                    NaN
# 2               ...                                    NaN
# 3               ...                                    NaN
# 4               ...                                    NaN
#
#   photo_location_country photo_location_city stats_views  stats_downloads  \
# 0                    NaN                 NaN    15854580           146388
# 1                    NaN                 NaN     3157825             8247
# 2                    NaN                 NaN     2159829             7064
# 3                    NaN                 NaN     2861489            11778
# 4                    NaN                 NaN     6037626            52263
#
#                                    ai_description ai_primary_landmark_name  \
# 0   school of jellyfish swimming in body of water                      NaN
# 1  surfer walking on body of water during daytime                      NaN
# 2   landscape photo of road beside field of grass                      NaN
# 3        closed up photo of orange lightened lamp                      NaN
# 4            white clouds and blue sky at daytime                      NaN
#
#   ai_primary_landmark_latitude ai_primary_landmark_longitude  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#    ai_primary_landmark_confidence
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
# [5 rows x 30 columns]

# %%
datasets['collections'].head()
# Out:
#       photo_id  collection_id    collection_title   photo_collected_at
# 0  --2IBUMom1I         162470  Majestical Sunsets  2016-03-15 17:04:25
# 1  --2IBUMom1I        4668070                Pose  2019-04-18 23:59:25
# 2  --2IBUMom1I        4172658                Guys  2019-02-02 14:40:14
# 3  --2IBUMom1I        9832457            business  2020-04-04 14:26:10
# 4  --2IBUMom1I        2143051     Travel / Places  2018-05-22 23:20:05

# %%
datasets['conversions'].head()
# Out:
#           converted_at conversion_type            keyword     photo_id  \
# 0  2020-02-28 19:17:37        download              birds  RLLR0oRz16Y
# 1  2020-02-28 19:20:15        download             winter  r6TLRDY4Ll0
# 2  2020-02-28 19:32:50        download             island  vh0FucFJ7pw
# 3  2020-02-28 19:39:59        download  full hd wallpaper  SbrZdkLtTCY
# 4  2020-02-28 19:49:56        download              river  x_gyAYzyeQA
#
#                       anonymous_user_id conversion_country
# 0  d5f2584b-3cde-4e6f-8875-2dde1373f9bb                 NL
# 1  ee639d04-e079-4737-a500-d3139cdfae9a                 KR
# 2  b97f3bdc-bfd2-478c-9a43-fe743ca4813c                 ID
# 3  5a15ec7e-9bf4-464c-9601-1ad731795a8d                 US
# 4  4bb2e232-498c-46d8-a02b-eb647ecff408                 IN

# %%
datasets['colors'].head()
# Out:
#       photo_id     hex  red  green  blue         keyword  ai_coverage  \
# 0  A2mjVkcix-w  101C23   16     28    35           black     0.613267
# 1  0ufkmj46xvU  625946   98     89    70  darkolivegreen     0.037172
# 2  0ufkmj46xvU  C7897A  199    137   122       rosybrown     0.024714
# 3  HY7Az9lZwB4  D18E46  209    142    70            peru     0.005867
# 4  HY7Az9lZwB4  A37343  163    115    67          sienna     0.010667
#
#    ai_score
# 0  0.635228
# 1  0.024936
# 2  0.111978
# 3  0.115786
# 4  0.109003

# %%
datasets['keywords'].head()
# Out:
#       photo_id  keyword  ai_service_1_confidence  ai_service_2_confidence  \
# 0  zzux2cH-F-A   spring                34.244873                86.833668
# 1  zzux2cH-F-A  compass                26.864105                      NaN
# 2  zzux2cH-F-A   nature                99.837990                95.966119
# 3  zzux2cH-F-A      jar                43.128902                      NaN
# 4  zzux2cH-F-A   flower                81.635406                      NaN
#
#   suggested_by_user
# 0                 f
# 1                 f
# 2                 f
# 3                 f
# 4                 f

# %% [markdown]
# ## Transform the SkyScanner geo.json to DataFrame

# %%
with open('geo.json') as f:
  geoJson = json.load(f)

# %%
countries = []
for continent in geoJson['Continents']:
    for country in continent['Countries']:
        countries.append({ 'Id': country['Id'], 'Name': country['Name'] })

# %%
pd.DataFrame(data=countries).head()
# Out:
#    Id        Name
# 0  MN    Mongolia
# 1  CN       China
# 2  KG  Kyrgyzstan
# 3  TJ  Tajikistan
# 4  BT      Bhutan

# %% [markdown]
# *SkyScanner* API will return a *2 character ISO code* for each country.
# We will use that code to index our images.
# However, we cannot be sure if the *Unsplash* dataset will have images for each and every country.
# So, we will a *default* Id code, and will map it to the *Travel* category.
# This will be useful as a fallback when we can't find images for a Country, to at least show something nice.

# %%
countries.append({
    'Id': 'default',
    'Name': 'Travel'
})

# %%
dfCountries = pd.DataFrame(data=countries)

# %%
dfCountries.tail()
# Out:
#           Id                      Name
# 243       MP  Northern Mariana Islands
# 244       TK                   Tokelau
# 245       VU                   Vanuatu
# 246       AU                 Australia
# 247  default                    Travel

# %% [markdown]
# We add an additional column `keyword` so we can merge it the *Unsplash* keyword dataframe

# %%
dfCountries['keyword'] = dfCountries['Name'].str.lower()

# %%
dfCountries.head()
# Out:
#    Id        Name     keyword
# 0  MN    Mongolia    mongolia
# 1  CN       China       china
# 2  KG  Kyrgyzstan  kyrgyzstan
# 3  TJ  Tajikistan  tajikistan
# 4  BT      Bhutan      bhutan

# %%
dfCountryKeywords = dfCountries.merge(datasets['keywords'], how='left')

# %%
dfCountryKeywords.sample(5)
# Out:
#            Id       Name    keyword     photo_id  ai_service_1_confidence  \
# 1045       NO     Norway     norway  q6vDxCXnvsk                      NaN
# 2645       AU  Australia  australia  uasc967z9fI                      NaN
# 864        IT      Italy      italy  OmelL9tVVno                      NaN
# 629        ES      Spain      spain  Lzx4J_Pb3sk                      NaN
# 3689  default     Travel     travel  6xTKw5ufGTY                      NaN
#
#       ai_service_2_confidence suggested_by_user
# 1045                      NaN                 t
# 2645                      NaN                 t
# 864                       NaN                 t
# 629                       NaN                 t
# 3689                      NaN                 t

# %%
dfCountryPhotos = dfCountryKeywords.merge( datasets['photos'], how='left')

# %%
dfCountryPhotos.sample(5)
# Out:
#            Id    Name keyword     photo_id  ai_service_1_confidence  \
# 124        JP   Japan   japan  sMP1im1Jbq4                      NaN
# 3433  default  Travel  travel  NVMF-cAHxCg                      NaN
# 2966  default  Travel  travel  pdRsf77OBoo                      NaN
# 2338       CA  Canada  canada  bQl2kRQyUE8                      NaN
# 2993  default  Travel  travel  oO15xC38wj4                      NaN
#
#       ai_service_2_confidence suggested_by_user  \
# 124                       NaN                 t
# 3433                      NaN                 t
# 2966                      NaN                 t
# 2338                      NaN                 t
# 2993                      NaN                 t
#
#                                     photo_url  \
# 124   https://unsplash.com/photos/sMP1im1Jbq4
# 3433  https://unsplash.com/photos/NVMF-cAHxCg
# 2966  https://unsplash.com/photos/pdRsf77OBoo
# 2338  https://unsplash.com/photos/bQl2kRQyUE8
# 2993  https://unsplash.com/photos/oO15xC38wj4
#
#                                         photo_image_url  \
# 124   https://images.unsplash.com/photo-152836123715...
# 3433  https://images.unsplash.com/photo-149859570799...
# 2966  https://images.unsplash.com/photo-1551482850-d...
# 2338  https://images.unsplash.com/photo-147697973503...
# 2993  https://images.unsplash.com/photo-145849666556...
#
#               photo_submitted_at              ...                \
# 124   2018-06-07 08:48:24.155065              ...
# 3433  2017-06-27 20:36:50.480293              ...
# 2966  2019-03-01 23:28:59.014058              ...
# 2338  2016-10-20 16:10:32.354776              ...
# 2993   2016-03-20 17:59:52.86722              ...
#
#      photo_location_longitude  photo_location_country  photo_location_city  \
# 124                139.703549                   Japan             Shinjuku
# 3433                      NaN                     NaN                  NaN
# 2966                      NaN                 Croatia                  NaN
# 2338              -123.240752                  Canada       West Vancouver
# 2993                 7.308953                 Germany                  NaN
#
#       stats_views stats_downloads  \
# 124      698678.0          6426.0
# 3433    3847651.0         19819.0
# 2966    2659178.0         30437.0
# 2338    2187424.0         14299.0
# 2993    1505781.0         16999.0
#
#                                          ai_description  \
# 124   people holding umbrella standing near pedestri...
# 3433  pine trees on rock formation near mountains un...
# 2966                       aerial photography of island
# 2338  two gray and orange backpacks on gray rocks at...
# 2993                                       green forest
#
#      ai_primary_landmark_name ai_primary_landmark_latitude  \
# 124                       NaN                          NaN
# 3433                      NaN                          NaN
# 2966                      NaN                          NaN
# 2338                      NaN                          NaN
# 2993                      NaN                          NaN
#
#      ai_primary_landmark_longitude ai_primary_landmark_confidence
# 124                            NaN                            NaN
# 3433                           NaN                            NaN
# 2966                           NaN                            NaN
# 2338                           NaN                            NaN
# 2993                           NaN                            NaN
#
# [5 rows x 36 columns]

# %% [markdown]
# From all that information we now have, we only need a couple of columns.
# We discard the rest

# %%
df = dfCountryPhotos[['Id', 'Name', 'photo_id', 'photo_image_url', 'photo_aspect_ratio']]

# %% [markdown]
# We need the *photo_aspect_ratio* to prevent our layout from shifting while the images are loading.

# %%
df.sample(5)
# Out:
#            Id         Name     photo_id  \
# 2933  default       Travel  rFh890jKgcs
# 2164       AQ   Antarctica  nvBfwtaUBnI
# 1849       HK    Hong Kong  WmCsa1gPlAc
# 2757       AU    Australia  Gk3Ot2WwLQM
# 1155       CH  Switzerland  z7tQUhBVOrY
#
#                                         photo_image_url  photo_aspect_ratio
# 2933  https://images.unsplash.com/photo-156410762896...                0.67
# 2164  https://images.unsplash.com/photo-146288838706...                1.33
# 1849  https://images.unsplash.com/photo-1551335844-0...                1.33
# 2757  https://images.unsplash.com/photo-157957089342...                1.47
# 1155  https://images.unsplash.com/photo-144775508655...                1.00

# %% [markdown]
# We remove any rows with missing info, since will add errors down the line

# %%
df = df.dropna()

# %% [markdown]
# Now that we have a nifty dataset, we are gonna index the rows by *Id*, for easy access.

# %%
g = df.groupby(
    [
        'Id',
        'Name'
    ],
    as_index=False
).apply(
    lambda group: group[[
        'photo_id',
        'photo_image_url',
        'photo_aspect_ratio'
    ]].to_dict('r')
).reset_index().rename(
    columns={
        0:'photos'
    }
)

# %%
imagesJson = json.loads(
    g.to_json(
        orient='records'
    )
)

# %% [markdown]
# Finally, we save our file as `images-by-country-id.json`

# %%
with open('images-by-country-id.json', 'w') as outfile:
    json.dump(imagesJson, outfile, indent=2)

# %% [markdown]
# You can find the latest compiled `CountryCode` to *Unsplash* images here
#
# https://github.com/facutk/wpxvuelos/blob/master/wp/wp-content/themes/xvuelos/assets/country-images-by-id/images-by-country-id.json
